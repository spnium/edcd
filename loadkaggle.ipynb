# %%
import kagglehub
kagglehub.dataset_download("gunavenkatdoddi/eye-diseases-classification")
# Out:
# ...
# 100%|██████████| 736M/736M [00:47<00:00, 16.3MB/s]
# Extracting files...
# '/home/pomp/.cache/kagglehub/datasets/gunavenkatdoddi/eye-diseases-classification/versions/1'

# %%
import splitfolders
path = "/home/pomp/.cache/kagglehub/datasets/gunavenkatdoddi/eye-diseases-classification/versions/1/dataset"
splitfolders.ratio(path, output="splited", seed=1337, ratio=(.7, 0.18,0.12))
# Out:
# Copying files: 4217 files [00:02, 1432.64 files/s]
